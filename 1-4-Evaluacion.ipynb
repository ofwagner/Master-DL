# %% [markdown]
# # Campaña "Seguro Vivienda" de compañía financiera

# %%
# %run 1-3-Modelado-v2.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2927 entries, 0 to 2926
# Data columns (total 28 columns):
# ID_Cliente                             2927 non-null object
# Fecha_Nacimiento                       2927 non-null object
# Fecha_Alta                             2927 non-null object
# Sexo                                   2927 non-null object
# ID_Zona                                2927 non-null object
# Productos_Vida                         2927 non-null int64
# Productos_Vehiculos                    2927 non-null int64
# Productos_Otros                        2927 non-null int64
# Gasto_Vida                             2927 non-null float64
# Gasto_Vehiculos                        2927 non-null float64
# Gasto_Otros                            2927 non-null float64
# Tipo_Familia                           2927 non-null float64
# Tipo_Pareja                            2927 non-null float64
# Tipo_Soltero                           2927 non-null float64
# ...

# %% [markdown]
# ## Informes

# %% [markdown]
# Además de métricas como accuracy, precisión o recall, es recomendable utilizar gráficas como la curva precisión-recall o la curva ROC:

# %% [markdown]
# ## Regresión Logística Lasso

# %%
y_score = modelo_logit_RS.predict_proba(X_test)[:,1]
y_score[0:100]
# Out:
# array([8.32460779e-02, 9.40845708e-04, 5.76457695e-02, 5.51661212e-02,
#        7.49151001e-02, 5.50395083e-02, 6.06737165e-02, 3.72963767e-03,
#        9.21546995e-03, 8.72561501e-02, 6.41020065e-02, 9.26571772e-02,
#        1.21651611e-01, 5.21712858e-02, 4.84519402e-02, 7.36016177e-02,
#        3.35761818e-02, 9.22979538e-01, 5.63416317e-01, 2.97534757e-02,
#        5.18456459e-02, 2.30246483e-02, 7.32447305e-02, 3.12426592e-01,
#        4.47447028e-02, 4.54167401e-02, 4.98151355e-02, 1.64904907e-02,
#        6.19435643e-02, 1.74986818e-01, 9.96836711e-01, 1.19252616e-02,
#        1.10310772e-01, 1.78571019e-01, 8.78476662e-02, 9.91649683e-03,
#        4.39057685e-02, 4.95231623e-01, 5.09655181e-02, 2.25997109e-02,
#        1.44345315e-02, 5.76329176e-02, 4.13933647e-02, 1.27967587e-01,
#        7.83376073e-01, 1.23446180e-01, 4.92549759e-02, 7.15756181e-01,
#        4.65092505e-01, 4.98599319e-03, 4.35372597e-02, 9.34929383e-01,
# ...

# %% [markdown]
# #### Accuracy

# %%
modelo_logit_RS.score(X_test,y_test)
# Out:
# 0.8668941979522184

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.9403367003367004

# %%
from sklearn.metrics import roc_curve, auc


# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# La regresión logística con una regularización l1 funciona muy bien (habiendo previamente balanceado los datos) la AUC es de 0.94 luego el modelo discrimina bastante bien.

# %% [markdown]
# ## Red Multicapa (1 capa)

# %%
y_score =mlp.predict(X_scale_test)
#y_score =y_score[:,1]>y_score[:,0]
y_score[0:100]
# Out:
# array([[4.96784878e-06],
#        [1.37662305e-03],
#        [2.95340084e-04],
#        [5.46239258e-04],
#        [7.59133763e-05],
#        [9.67198575e-05],
#        [4.52886382e-03],
#        [9.14436612e-07],
#        [3.63827826e-06],
#        [4.45986725e-03],
#        [1.25622991e-02],
#        [6.39494061e-02],
#        [1.54524269e-02],
#        [7.79271068e-04],
#        [8.48955096e-05],
#        [2.33734372e-05],
#        [2.10731359e-05],
#        [5.93294024e-01],
#        [1.69865921e-01],
#        [7.73609281e-05],
#        [1.22522900e-03],
#        [1.31666049e-04],
#        [4.83756827e-04],
#        [1.74758863e-03],
#        [2.74901139e-03],
#        [1.91109953e-04],
#        [1.29321893e-03],
#        [1.75623616e-04],
#        [1.84907403e-05],
#        [2.85018847e-04],
#        [8.64275217e-01],
#        [2.15180785e-06],
#        [3.17558721e-02],
#        [7.34349759e-03],
#        [1.29251136e-02],
#        [2.14647784e-07],
#        [1.19808046e-02],
# ...

# %% [markdown]
# #### Accuracy

# %%
mlp.evaluate(X_scale_test,y_test)[1]
# Out:
# 879/879 [==============================] - 0s 23us/step
# 0.9522184300341296

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.9083501683501682

# %%
from sklearn.metrics import roc_curve, auc



# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# La red sencilla clasifica bien tiene un AUC lígeramente menor al modelo logístico, aunque el accuracy de la red es superior

# %% [markdown]
# ## Red Multicapa (Deep)

# %%
y_score =mlp2.predict(X_scale_test)
#y_score =y_score[:,1]>y_score[:,0]
y_score[0:100]
# Out:
# array([[3.0709971e-10],
#        [2.0880488e-09],
#        [1.1267359e-09],
#        [1.7352777e-06],
#        [2.4974352e-06],
#        [8.2436607e-05],
#        [8.2975021e-03],
#        [1.2197994e-08],
#        [3.0186069e-07],
#        [8.7161531e-08],
#        [5.5636611e-09],
#        [8.4418971e-08],
#        [2.1026499e-07],
#        [8.2101615e-06],
#        [5.5660276e-09],
#        [3.9619579e-05],
#        [7.4503021e-07],
#        [9.9389380e-01],
#        [1.2926204e-03],
#        [2.1081908e-06],
#        [5.3180468e-08],
#        [3.2624567e-10],
#        [3.9660986e-11],
#        [1.5249360e-09],
#        [1.6757356e-08],
#        [1.4060304e-08],
#        [4.5007029e-09],
#        [1.5291425e-08],
#        [1.2638153e-06],
#        [2.3692239e-06],
#        [4.1763313e-04],
#        [5.0881391e-13],
#        [7.6379354e-07],
#        [5.1107063e-06],
#        [3.5150552e-07],
#        [7.4201947e-12],
#        [1.1857886e-08],
#        [5.6081405e-03],
# ...

# %% [markdown]
# #### Accuracy

# %%
mlp2.evaluate(X_scale_test,y_test)[1]
# Out:
# 879/879 [==============================] - 0s 39us/step
# 0.9374288964732651

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.8751066217732885

# %%
from sklearn.metrics import roc_curve, auc


# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Cuanto más compleja es la red más dificil es de parametrizar y el tener datos no balanceados que hemos balanceado sin estratifcar parece que afecta al poder discriminante del modelo.

# %% [markdown]
# ## Red Multicapa Ridge

# %%
y_score =mlp3.predict(X_scale_test)
#y_score =y_score[:,1]>y_score[:,0]
y_score[0:100]
# Out:
# array([[7.3652714e-03],
#        [4.3203868e-03],
#        [2.2930116e-03],
#        [3.2414449e-03],
#        [1.8990880e-03],
#        [1.7577340e-04],
#        [3.3329555e-03],
#        [1.9372065e-04],
#        [3.9674822e-04],
#        [2.3817372e-02],
#        [6.1063939e-03],
#        [3.8153948e-03],
#        [7.3471065e-03],
#        [3.9478784e-04],
#        [4.6806899e-04],
#        [2.1079600e-04],
#        [1.3897085e-04],
#        [4.4141155e-01],
#        [3.3505642e-01],
#        [5.6459743e-05],
#        [6.8941730e-04],
#        [6.9317548e-03],
#        [6.7453948e-04],
#        [5.9514386e-03],
#        [1.4653429e-03],
#        [2.8085368e-04],
#        [2.1921369e-04],
#        [1.7576796e-03],
#        [2.7480762e-04],
#        [9.6207634e-03],
#        [4.6794957e-01],
#        [6.2279747e-04],
#        [1.0353276e-01],
#        [1.6033220e-01],
#        [7.6755893e-04],
#        [1.4380312e-03],
#        [6.0006353e-04],
#        [4.4730730e-02],
# ...

# %% [markdown]
# #### Accuracy

# %%
mlp3.evaluate(X_scale_test,y_test)[1]
# Out:
# 879/879 [==============================] - 0s 34us/step
# 0.9579067121729238

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.9495847362514029

# %%
from sklearn.metrics import roc_curve, auc


# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Mejora en Accuracy y AUC

# %% [markdown]
# ## Red Multicapa Lasso

# %%
y_score =mlp4.predict(X_scale_test)
#y_score =y_score[:,1]>y_score[:,0]
y_score[0:100]
# Out:
# array([[2.52379890e-04],
#        [2.38205848e-05],
#        [2.20031201e-04],
#        [6.20318024e-05],
#        [2.08748286e-04],
#        [4.12127483e-05],
#        [5.75376500e-04],
#        [8.58657313e-06],
#        [2.98733394e-05],
#        [1.19743182e-03],
#        [1.76213391e-03],
#        [2.04492695e-04],
#        [6.00409636e-04],
#        [1.23681428e-04],
#        [4.74717846e-04],
#        [2.35517480e-04],
#        [7.57127564e-05],
#        [8.55768919e-01],
#        [7.99386203e-01],
#        [3.93373302e-05],
#        [6.41084509e-04],
#        [1.95948333e-02],
#        [7.43599725e-04],
#        [5.78378327e-04],
#        [3.09097435e-04],
#        [3.03140987e-04],
#        [4.11673391e-04],
#        [1.69772204e-06],
#        [3.32504715e-04],
#        [2.98133329e-03],
#        [1.76713951e-02],
#        [1.86697016e-05],
#        [4.75202949e-04],
#        [5.24834497e-03],
#        [7.47556565e-04],
#        [1.37009793e-05],
#        [1.33874462e-04],
# ...

# %% [markdown]
# #### Accuracy

# %%
mlp4.evaluate(X_scale_test,y_test)[1]
# Out:
# 879/879 [==============================] - 0s 35us/step
# 0.9601820250284414

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.9319191919191919

# %%
from sklearn.metrics import roc_curve, auc


# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# La restricción l1 similar al modelo con restricción l2

# %% [markdown]
# ## Red Multicapa Lasso: 2 unidades de salida

# %%
y_score =mlp5.predict(X_scale_test)[:,1]
#y_score =y_score[:,1]>y_score[:,0]
y_score[0:100]
#y_test[0:100]
# Out:
# array([4.77326939e-05, 1.78993490e-04, 2.89172840e-05, 5.43004462e-05,
#        7.04861246e-04, 2.76772305e-04, 4.72915452e-03, 4.67702193e-06,
#        1.05905719e-05, 6.08237344e-04, 3.25761765e-04, 6.03797438e-04,
#        1.49026077e-04, 3.96606702e-05, 3.31639349e-05, 1.11836467e-04,
#        2.85553077e-04, 4.18452680e-01, 9.11744058e-01, 1.91044146e-05,
#        9.50196991e-04, 1.79349343e-04, 8.20942130e-03, 2.58449581e-03,
#        1.04900384e-04, 4.77048568e-04, 2.78580610e-05, 3.65151152e-07,
#        4.39721553e-05, 8.41878238e-04, 4.75489050e-01, 1.53673636e-06,
#        6.39513507e-03, 3.35321034e-04, 1.76860107e-04, 2.24504620e-05,
#        3.40544590e-04, 3.84934321e-02, 8.08547629e-05, 8.01878195e-06,
#        6.02918553e-05, 6.90540113e-03, 3.62418999e-04, 5.63316280e-04,
#        7.35839596e-04, 1.08126915e-05, 3.20864609e-04, 6.36840938e-04,
#        1.70741584e-02, 2.22839589e-07, 2.72434234e-04, 1.89243478e-03,
# ...

# %% [markdown]
# #### Accuracy

# %%
mlp5.evaluate(X_scale_test,y_cat_test)[1]
# Out:
# 879/879 [==============================] - 0s 35us/step
# 0.962457337883959

# %% [markdown]
# #### ROC

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_score)
# Out:
# 0.8909988776655444

# %%
from sklearn.metrics import roc_curve, auc
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc[i] = auc(fpr, tpr)

# Compute micro-average ROC curve and ROC area
fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ROC bastante cercana a la del modelo logístico, pero el usar dos unidades de salida parece que empeora el modelo.

# %% [markdown]
# ### Consideraciones finales

# %% [markdown]
# De todos los modelos analizados en este caso nos quedamos con la red de una capa: buen AUC y buen accuracy, el modelo de regresión logística usando todas las variables y usando una regularización l1 es bastante cercano, aunque tienen un accuracy inferior
#
# Por facilidad hemos usado sólo las variables cuantitativas de los datos, pero se podría haber añadido variables como: antiguedad (Fecha de Alta), edad (Fecha de Nacimiento) y sexo (dummy). En la práctica he preferido centrarme en las construcción de modelos usando disitntas técnicas más que en probar y crear distintas variables sintéticas. Adjunto un notebook "Anexo" donde primero realizo un remuestreo para intentar mejorar el modelo de Deep Learning.
#
# Para verificar el poder discriminante de los modelos he usado la ROC ya que es la que me parece más adecuada.

# %% [markdown]
# Para finalizar calcularemos para los clientes nuevos la probabilidad de contratar el seguro.

# %%
datos2.head()
# Out:
#   ID_Cliente Fecha_Nacimiento  Fecha_Alta    Sexo ID_Zona  Productos_Vida  \
# 0      C2172       05/10/1981  04/02/2005  Hombre   Z0403               1
# 1      C3005       05/04/1974  26/11/1995  Hombre   Z0403               0
# 2      C1627       21/09/1983  27/12/2004   Mujer   Z0700               0
# 3      C3120       16/02/1986  24/09/2007   Mujer   Z0700               0
# 4      C0649       24/01/1945  02/12/1967  Hombre   Z1023               0
#
#    Productos_Vehiculos  Productos_Otros  Gasto_Vida  Gasto_Vehiculos  \
# 0                    2                2      735.14          2535.49
# 1                    0                1        0.00             0.00
# 2                    1                1        0.00          3195.94
# 3                    3                0        0.00          4610.12
# 4                    0                0        0.00             0.00
#
#              ...              Poblacion_Trabajador_Cualificado  \
# ...

# %%
X_scale_datos2 = scale.transform(X_test_2) # aplicamos escalado del modelo de los datos de entrenamiento

#probabilidad_contratación = modelo_logit_RS.predict_proba(datos2._get_numeric_data())[:,1]

probabilidad_contratación  = mlp3.predict(X_scale_datos2)

# %%
datos3 = datos2


datos3['probabilidad_contratación'] = probabilidad_contratación


datos3[['ID_Cliente','probabilidad_contratación']].head()
# Out:
#   ID_Cliente  probabilidad_contratación
# 0      C2172                   0.017801
# 1      C3005                   0.005109
# 2      C1627                   0.054744
# 3      C3120                   0.109172
# 4      C0649                   0.000025

# %% [markdown]
# Es muy habitual utilizar estas gráficas, especialmente la curva ROC, para decidir si los resultados son satisfactorios. Cuanto mayor sea el área que queda bajo la curva, mejores son los resultados del modelo.

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Utiliza gráficas (estas u otras que puedas encontrar útiles) para que el cliente pueda hacer una valoración final de los resultados. Las curvas ROC y Lift son de mucha ayuda normalmente, ya que miden de forma directa cómo impacta la calidad del modelo en el negocio.

# %% [markdown]
# ## Referencias

# %% [markdown]
# * http://scikit-learn.org/stable/modules/model_evaluation.html
# * http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
