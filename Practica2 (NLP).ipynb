# %% [markdown]
# ## Cargamos librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from IPython.display import SVG

from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
from keras.layers import Input, Dense, SimpleRNN, Dropout, Embedding, Flatten
from keras.models import Model
from keras import regularizers
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import model_to_dot
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from keras.optimizers import Nadam

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

import string
import tensorflow as tf

tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=4))
pd.set_option('max_colwidth', 1000)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("sentiment.txt", sep="\t", header=None )

# %%
df.columns=["label", "text"]

# %%
df.head()
# Out:
#    label  \
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
#                                                                                                                            text
# 0                                                                                       The Da Vinci Code book is just awesome.
# 1  this was the first clive cussler i've ever read, but even books like Relic, and Da Vinci code were more plausible than this.
# 2                                                                                              i liked the Da Vinci Code a lot.
# 3                                                                                              i liked the Da Vinci Code a lot.
# 4                                                      I liked the Da Vinci Code but it ultimatly didn't seem to hold it's own.

# %% [markdown]
# Quitamos signos de puntuación

# %%
#df["text"] = df["text"].str.replace("[{}]".format(string.punctuation), "")
df["text"] = df["text"].str.replace('[^\w\s]','')

# %%
df.head()
# Out:
#    label  \
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#
#                                                                                                                        text
# 0                                                                                    The Da Vinci Code book is just awesome
# 1  this was the first clive cussler ive ever read but even books like Relic and Da Vinci code were more plausible than this
# 2                                                                                           i liked the Da Vinci Code a lot
# 3                                                                                           i liked the Da Vinci Code a lot
# 4                                                     I liked the Da Vinci Code but it ultimatly didnt seem to hold its own

# %%
df.iloc[30,:]
# Out:
# label                                    1
# text     Book  s  I love The Da Vinci Code
# Name: 30, dtype: object

# %% [markdown]
# Como el df está ordenado por sentimiento positivo y negativo, lo "desordenamos"

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#    label  \
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#
#                                                                                                                    text
# 0                    I either LOVE Brokeback Mountain or think its great that homosexuality is becoming more acceptable
# 1                                                                                     Brokeback Mountain was so awesome
# 2                                Then snuck into Brokeback Mountain which is the most depressing movie I have ever seen
# 3                                          the story of Harry Potter is a deep and profound one and I love Harry Potter
# 4   she helped me bobbypin my insanely cool hat to my head and she laughed at my stupid brokeback mountain cowboy jokes

# %%
text_df= df.text

# %%
text_df
# Out:
# 0                                                                                                         I either LOVE Brokeback Mountain or think its great that homosexuality is becoming more acceptable
# 1                                                                                                                                                                          Brokeback Mountain was so awesome
# 2                                                                                                                     Then snuck into Brokeback Mountain which is the most depressing movie I have ever seen
# 3                                                                                                                               the story of Harry Potter is a deep and profound one and I love Harry Potter
# 4                                                                                        she helped me bobbypin my insanely cool hat to my head and she laughed at my stupid brokeback mountain cowboy jokes
# 5                                                                                                                                                                               I enjoy reading Harry Potter
# 6                                                                                                                                                                              The Da Vinci Code was awesome
# 7                                                                                                                                                                              The Da Vinci Code was awesome
# 8                                                                                                                                                                                    I hate Harry Potter too
# 9                                                                                                                           I think this bolsters my arguments that both England and the Da Vinci Code sucks
# 10                                                                                                                                                                                       I hate Harry Potter
# 11                                                                                                                                                                   Brokeback Mountain was an AWESOME movie
# 12                                                                                                                                                                                       da vinci code sucks
# 13                                                                                                        I either LOVE Brokeback Mountain or think its great that homosexuality is becoming more acceptable
# 14                                                                                            So as felicias mom is cleaning the table felicia grabs my keys and we dash out like freakin mission impossible
# 15                                                                                                                                                                                      Da Vinci Code sucked
# 16                                                                                                                                                                        da vinci code was an awesome movie
# 17                                                                                       she helped me bobbypin my insanely cool hat to my head and she laughed at my stupid brokeback mountain cowboy jokes
# 18                                                                                                                              the story of Harry Potter is a deep and profound one and I love Harry Potter
# 19                                                                                                                                                       i heard da vinci code sucked soo much only 25 stars
# 20                                                                                                                                        the people who are worth it know how much i love the da vinci code
# 21                                                                                                                                                                       The Harry Potter scar would be cool
# 22                                                                           You know the Harry Potter books are decent enough and I â m glad they â ve got kids reading and reading big thick books at that
# 23                                                                                                                                                   I wanted desperately to loveThe Da Vinci Code as a film
# 24                                                                                                                                                                                     Harry Potters awesome
# 25                                                                                                                                                                  The Da Vinci Code was absolutely AWESOME
# 26                                                                                             As I sit here watching the MTV Movie Awards I am reminded of how much I despised the movie Brokeback Mountain
# 27                                                                                                                                                 Always knows what I want not guy crazy hates Harry Potter
# 28                                                                               I love the Harry Potter series if you can count that as  a  book also Catcher In the Tye Jane Eyre The Virgin Suicides yeah
# 29                                                                                                                                                                                 I love Brokeback Mountain
#                                                                                                         ...
# 6888                                                                                                                             Combining the opinion  review from Gary and Gin Zen The Da Vinci Code sucks
# 6889                                                                                                                                                                           Brokeback Mountain was boring
# 6890                                                                                                                                        I hate Harry Potter that daniel wotshisface needs a fucking slap
# 6891                                                                                                                                                             So Brokeback Mountain was really depressing
# 6892                                                                                                                                                    The Da Vinci Code was awesome I cant wait to read it
# 6893                                                                                                                                                                         Love luv lubb the Da Vinci Code
# 6894                                                                                                                           I hate Harry Potter its retarted gay and stupid and theres only one Black guy
# 6895                                                                                                                                          Harry Potter is AWESOME I dont care if anyone says differently
# 6896                                                                                                                                     Other than that all Ive heard is that the Da Vinci Code kinda sucks
# 6897                                                                                                                          I like Mission Impossible movies because you never know whos on the right side
# 6898                                                                                                                           I hate Harry Potter its retarted gay and stupid and theres only one Black guy
# 6899                                                                                                                                                                          man i loved brokeback mountain
# 6900                                                                                                                                                                 Brokeback Mountain was an AWESOME movie
# 6901                                                                                        Which is why i said silent hill turned into reality coz i was hella like goin mission impossible down that bitch
# 6902    Harry Potter dragged Draco Malfoy â s trousers down past his hips and sucked him into his throat with vigor making whimpering noises and panting and groaning around the blonds rockhard aching cock
# 6903                                                                                                                                 Love the Harry Potter series though I try not to talk about it too much
# 6904                                                                                                                                                                                I love The Da Vinci Code
# 6905                                                                                                                                          Harry Potter is AWESOME I dont care if anyone says differently
# 6906                                                                        I want to be here because I love Harry Potter and I really want a place where people take it serious but it is still so much fun
# 6907                                                                                                                     His new track for Mission Impossible 3 is probably the dumbest thing Ive ever heard
# 6908                                                                                                                                           Da Vinci Code  Up Up Down Down Left Right Left Right B A SUCK
# 6909                                                              I think I hate Harry Potter because it outshines much better reading material out there and the movies are just plain stupid to begin with
# 6910                                                                                                                                                                              mission impossible 2 rocks
# 6911                                                                                                                                                                                     I love Harry Potter
# 6912                               Because I would like to make friends who like the same things I like and I really like Harry Potter so I thought that joining a community like this would be a good start
# 6913                                                                                                                                                                   These Harry Potter movies really suck
# 6914                                                                                                                  Then snuck into Brokeback Mountain which is the most depressing movie I have ever seen
# 6915                                                                                                                                                  Hes likeYEAH I GOT ACNE AND I LOVE BROKEBACK MOUNTAIN
# 6916                                                                                                                                                                               i like mission impossible
# 6917    Harry Potter dragged Draco Malfoy â s trousers down past his hips and sucked him into his throat with vigor making whimpering noises and panting and groaning around the blonds rockhard aching cock
# Name: text, Length: 6918, dtype: object

# %% [markdown]
# Convertimos palabras a números

# %%
max_palabras=2500 #2235 palabras
tokenizer = Tokenizer(num_words=max_palabras)
tokenizer.fit_on_texts(text_df)
sequences = tokenizer.texts_to_sequences(text_df)

# %%
len(tokenizer.word_index)
# Out:
# 2235

# %%
sequences
# Out:
# [[1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [8, 9, 14, 27, 15],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [1, 350, 71, 5, 4],
#  [2, 7, 6, 10, 14, 15],
#  [2, 7, 6, 10, 14, 15],
#  [1, 26, 5, 4, 93],
#  [1, 58, 57, 931, 29, 932, 22, 140, 933, 3, 2, 7, 6, 10, 24],
#  [1, 26, 5, 4],
#  [8, 9, 14, 54, 15, 20],
#  [7, 6, 10, 24],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [7, 6, 10, 25],
#  [7, 6, 10, 14, 54, 15, 20],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [2, 5, 4, 615, 68, 38, 150],
#  [35,
#   42,
#   2,
#   5,
#   4,
#   301,
#   59,
#   616,
#   617,
#   3,
#   1,
#   100,
#   508,
#   374,
#   305,
#   100,
#   934,
#   129,
#   391,
#   71,
#   3,
#   71,
#   121,
#   935,
#   301,
#   99,
#   22],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [5, 618, 15],
#  [2, 7, 6, 10, 14, 112, 15],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1, 11, 8, 9],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [37, 936, 2, 7, 6, 10, 12, 54, 15, 88],
#  [1, 49, 5, 4, 392],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [142, 1, 11, 8, 9],
#  [8, 9, 12, 77, 69],
#  [1, 11, 2, 7, 6, 10],
#  [1, 97, 19, 375, 937, 938, 619, 3, 103, 17, 16, 44, 51, 14, 40, 27, 15],
#  [29, 259, 82, 34, 90, 8, 9],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [7, 6, 10, 24],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [8, 9, 14, 91],
#  [81,
#   14,
#   40,
#   112,
#   620,
#   76,
#   939,
#   100,
#   621,
#   41,
#   31,
#   29,
#   622,
#   456,
#   3,
#   365,
#   2,
#   7,
#   6,
#   10,
#   298,
#   30,
#   25,
#   81,
#   509,
#   92,
#   76,
#   21],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [7, 6, 10, 24],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [7, 6, 10, 24],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1,
#   42,
#   35,
#   59,
#   296,
#   510,
#   309,
#   90,
#   940,
#   1,
#   11,
#   105,
#   511,
#   5,
#   4,
#   46,
#   623,
#   941,
#   511,
#   2,
#   942,
#   12,
#   3,
#   312,
#   151,
#   38,
#   5,
#   4],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [2, 943, 20, 14, 8, 9, 51, 14, 323, 32, 78],
#  [1, 11, 2, 7, 6, 10],
#  [1,
#   116,
#   11,
#   17,
#   16,
#   302,
#   63,
#   21,
#   303,
#   166,
#   56,
#   624,
#   3,
#   310,
#   944,
#   76,
#   945,
#   625],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [7, 6, 10, 12, 15],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [1, 114, 2, 104, 17, 16],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [277, 1, 48, 8, 9],
#  [142, 1, 48, 8, 9],
#  [1, 11, 8, 9],
#  [1, 26, 5, 4],
#  [7, 6, 10, 24],
#  [1, 11, 8, 9],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [2, 7, 6, 10, 14, 112, 15],
#  [1, 11, 2, 7, 6, 10],
#  [2, 7, 6, 10, 12, 15],
#  [17, 16, 293, 14, 15],
#  [1, 11, 8, 9],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [148, 5, 4, 33, 32, 43],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [17, 16, 44, 14, 153],
#  [1, 26, 5, 4],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [1, 48, 2, 7, 6, 10, 3, 2, 18],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [7, 6, 10, 12, 15],
#  [19,
#   38,
#   946,
#   5,
#   4,
#   3,
#   2,
#   512,
#   31,
#   457,
#   2,
#   422,
#   12,
#   626,
#   13,
#   947,
#   948,
#   31,
#   627,
#   324,
#   2,
#   949,
#   37,
#   1,
#   306,
#   628,
#   39,
#   21],
#  [1, 114, 2, 104, 17, 16],
#  [1, 11, 5, 4],
#  [1, 93, 18, 5, 4],
#  [2, 7, 6, 10, 14, 112, 15],
#  [17, 16, 44, 14, 15],
#  [17, 16, 12, 126, 19, 38, 27, 15, 57, 393],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [7, 6, 10, 25],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [513, 339, 13, 5, 4, 950, 53, 13, 951, 19, 458, 13, 629, 5, 4, 952],
#  [17, 16, 44, 14, 153],
#  [17, 16, 44, 14, 153],
#  [169, 146, 72, 1, 11, 8, 9],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [1, 26, 5, 4],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [1, 98, 423, 394, 104, 3, 47, 309, 953, 2, 7, 6, 10, 51, 27, 343, 12, 15],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [8, 9, 25],
#  [53, 22, 37, 332, 21, 14, 29, 630, 81, 12, 50, 5, 4],
#  [8, 9, 12, 77, 69],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [148, 5, 4, 33, 32, 43],
#  [1, 11, 8, 9],
#  [7, 6, 10, 25],
#  [2, 7, 6, 10, 14, 54, 15, 20],
#  [7, 6, 10, 24],
#  [7, 6, 10, 25],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [8, 9, 14, 91],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [277, 1, 48, 8, 9],
#  [142, 1, 48, 8, 9],
#  [11, 186, 279, 2, 7, 6, 10],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [29, 259, 82, 34, 90, 8, 9],
#  [2, 7, 6, 10, 25, 121, 118],
#  [316,
#   631,
#   67,
#   514,
#   19,
#   632,
#   67,
#   633,
#   90,
#   366,
#   5,
#   4,
#   43,
#   67,
#   157,
#   75,
#   19,
#   38,
#   634,
#   340,
#   108,
#   67,
#   635,
#   636,
#   70],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [8, 9, 298, 30, 25],
#  [7, 6, 10, 24],
#  [1, 11, 5, 4],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [17, 16, 44, 14, 77, 15],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [8, 9, 14, 91],
#  [17, 16, 293, 14, 15],
#  [309,
#   317,
#   65,
#   312,
#   304,
#   19,
#   56,
#   954,
#   1,
#   114,
#   2,
#   7,
#   6,
#   10,
#   395,
#   82,
#   93,
#   515,
#   96,
#   516,
#   637,
#   291,
#   1,
#   11,
#   2,
#   7,
#   6,
#   10,
#   291,
#   117,
#   1,
#   303,
#   350,
#   955,
#   956,
#   3,
#   1,
#   48,
#   2,
#   7,
#   6,
#   10,
#   27,
#   57,
#   459,
#   957,
#   19,
#   56,
#   3,
#   21,
#   638,
#   958,
#   517,
#   50,
#   41,
#   31,
#   2,
#   424,
#   959,
#   22,
#   2,
#   960,
#   333,
#   367,
#   19,
#   961,
#   291,
#   1,
#   40,
#   98,
#   7,
#   6,
#   10,
#   51,
#   14,
#   15,
#   108,
#   2,
#   115,
#   100,
#   291,
#   2,
#   7,
#   6,
#   10,
#   12,
#   153,
#   63,
#   35,
#   98,
#   21,
#   28,
#   639,
#   28,
#   35,
#   98,
#   313,
#   962,
#   291,
#   1,
#   48,
#   2,
#   7,
#   6,
#   10,
#   291,
#   1,
#   11,
#   71,
#   2,
#   7,
#   6,
#   10,
#   291,
#   294,
#   460,
#   35,
#   2,
#   7,
#   6,
#   10,
#   12,
#   54,
#   15,
#   88,
#   291,
#   101,
#   147,
#   29,
#   158,
#   334,
#   38,
#   13,
#   396,
#   640,
#   23,
#   1,
#   48,
#   2,
#   7,
#   6,
#   10,
#   963,
#   291,
#   3,
#   1,
#   14,
#   397,
#   964,
#   39,
#   29,
#   461,
#   965,
#   311,
#   366,
#   48,
#   2,
#   7,
#   6,
#   10,
#   27,
#   30,
#   22,
#   1,
#   14,
#   641,
#   19,
#   310,
#   642,
#   966,
#   398,
#   62,
#   2,
#   313,
#   167,
#   967],
#  [29, 259, 82, 34, 90, 8, 9],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [2, 7, 6, 10, 14, 112, 15],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [37, 101, 119, 1, 518, 643, 968, 327, 339, 296, 125, 8, 9, 51, 14, 69],
#  [277, 1, 48, 8, 9],
#  [7, 6, 10, 14, 54, 15, 20],
#  [8, 9, 14, 91],
#  [8, 9, 14, 27, 15],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [8, 9, 14, 27, 15],
#  [71, 57, 181, 35, 334, 644, 2, 519, 22, 1, 26, 2, 7, 6, 10, 51, 520, 521],
#  [8, 9, 14, 94, 314, 153],
#  [27, 8, 9, 14, 32, 64],
#  [1, 93, 18, 5, 4],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [27, 8, 9, 14, 32, 64],
#  [8, 9, 14, 91],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [1, 11, 5, 4],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [8, 9, 14, 91],
#  [8, 9, 14, 133],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [61,
#   344,
#   96,
#   13,
#   645,
#   31,
#   376,
#   328,
#   37,
#   969,
#   1,
#   58,
#   2,
#   7,
#   6,
#   10,
#   24,
#   1,
#   145,
#   646,
#   2,
#   970,
#   31,
#   141,
#   21],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [7, 6, 10, 25],
#  [1, 11, 5, 4],
#  [2, 7, 6, 10, 12, 15],
#  [7, 6, 10, 12, 15],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1, 971, 22, 5, 4, 12, 13, 127, 98, 76, 972],
#  [8, 9, 14, 27, 15],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [1, 11, 5, 4],
#  [22, 522, 5, 4],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [2, 104, 17, 16, 14, 15, 3, 57, 41, 368, 298, 92, 93],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [2, 7, 6, 10, 24, 523],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [108, 2, 115, 17, 16, 44, 14, 15],
#  [2, 7, 6, 10, 12, 15],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [294, 60, 13, 121, 647, 399, 170, 37, 1, 18, 17, 16],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [7, 6, 10, 24],
#  [7, 6, 10, 12, 54, 15, 20],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [1, 11, 2, 7, 6, 10],
#  [7, 6, 10, 12, 15],
#  [1, 48, 398, 17, 16],
#  [7, 6, 10, 24],
#  [2, 7, 6, 10, 32, 12, 54, 15, 88, 3, 35, 351, 296, 307, 310, 21],
#  [1, 11, 5, 4],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1, 295, 8, 9],
#  [1, 26, 5, 4],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 11, 5, 4],
#  [7, 6, 10, 24],
#  [8, 9, 14, 91],
#  [1, 114, 2, 104, 17, 16],
#  [2, 7, 6, 10, 14, 648, 973, 462, 99, 974, 975, 976],
#  [7, 6, 10, 24, 38],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [1, 11, 8, 9],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [8, 9, 14, 133],
#  [8, 9, 14, 27, 15],
#  [1, 11, 8, 9],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [294, 321, 335, 22, 7, 6, 10, 25],
#  [8, 9, 14, 91],
#  [1, 18, 5, 4, 13, 308, 93],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [7, 6, 10, 12, 15],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [142, 1, 48, 8, 9],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [8, 9, 14, 133],
#  [8, 9, 14, 133],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [1, 11, 8, 9],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [7, 6, 10, 24, 38],
#  [7, 6, 10, 25, 28, 649],
#  [2, 7, 6, 10, 12, 15],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [7, 6, 10, 12, 15],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [7, 6, 10, 12, 15],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [463,
#   56,
#   462,
#   28,
#   1,
#   307,
#   650,
#   19,
#   977,
#   317,
#   978,
#   979,
#   6,
#   10,
#   102,
#   43,
#   29,
#   980,
#   102,
#   43,
#   29,
#   981,
#   53,
#   982,
#   31,
#   13,
#   983],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [2, 7, 6, 10, 14, 15],
#  [336, 12, 1, 369, 2, 7, 6, 10],
#  [37,
#   63,
#   352,
#   425,
#   2,
#   651,
#   984,
#   8,
#   9,
#   426,
#   89,
#   25,
#   985,
#   324,
#   400,
#   76,
#   13,
#   986],
#  [1, 11, 8, 9],
#  [1, 11, 8, 9],
#  [169, 146, 72, 1, 11, 8, 9],
#  [2, 7, 6, 10, 25],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [1, 11, 5, 4],
#  [7, 6, 10, 12, 15],
#  [277, 1, 48, 8, 9],
#  [17, 16, 109, 162],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [2, 7, 6, 10, 25, 121, 118],
#  [1, 93, 18, 5, 4],
#  [142, 1, 48, 8, 9],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [7, 6, 10, 24],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [17,
#   16,
#   109,
#   14,
#   13,
#   69,
#   123,
#   22,
#   327,
#   56,
#   652,
#   653,
#   1,
#   58,
#   90,
#   21,
#   27,
#   69,
#   21,
#   14,
#   22,
#   1,
#   401,
#   654,
#   53,
#   464,
#   465],
#  [8, 9, 14, 91],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [7, 6, 10, 24, 38],
#  [325, 987, 37, 1, 26, 5, 4, 37, 988],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [277, 1, 48, 8, 9],
#  [17, 16, 109, 162],
#  [1, 26, 2, 7, 6, 10],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [8, 9, 12, 77, 69],
#  [1, 120, 2, 7, 6, 10, 24, 28, 13, 20],
#  [1, 11, 2, 17, 16, 33, 37, 57, 85, 12, 32, 989],
#  [1, 11, 5, 4],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [655,
#   311,
#   352,
#   425,
#   2,
#   466,
#   135,
#   14,
#   13,
#   308,
#   31,
#   524,
#   90,
#   62,
#   8,
#   9,
#   14,
#   656,
#   76,
#   657,
#   31,
#   13,
#   34,
#   20,
#   22,
#   402,
#   339,
#   22,
#   525,
#   12,
#   370],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [7, 6, 10, 12, 15],
#  [1, 93, 18, 5, 4],
#  [2, 7, 6, 10, 12, 15],
#  [7, 6, 10, 14, 54, 15, 20],
#  [7, 6, 10, 24],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [169, 146, 72, 1, 11, 8, 9],
#  [1, 26, 5, 4],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [8, 9, 14, 54, 15, 20],
#  [80, 27, 91, 7, 6, 10],
#  [277, 1, 48, 8, 9],
#  [7, 6, 10, 12, 15],
#  [2, 7, 6, 10, 12, 15],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [1, 11, 5, 4],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [17, 16, 44, 12, 15, 658, 172, 398],
#  [2, 7, 6, 10, 25, 121, 118],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [1, 58, 526, 8, 9, 403, 38, 298, 990, 3, 329, 659],
#  [1, 11, 2, 7, 6, 10],
#  [1, 11, 5, 4],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [1, 11, 2, 7, 6, 10],
#  [1,
#   26,
#   26,
#   26,
#   106,
#   315,
#   3,
#   17,
#   16,
#   33,
#   37,
#   1,
#   58,
#   1,
#   334,
#   307,
#   292,
#   57,
#   341,
#   41,
#   527],
#  [8, 9, 14, 54, 15, 20],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [142, 1, 48, 8, 9],
#  [1, 11, 2, 7, 6, 10],
#  [11, 186, 279, 2, 7, 6, 10],
#  [1, 295, 8, 9, 3, 60, 23, 2, 179, 991, 74, 139],
#  [17, 16, 44, 14, 153],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [148, 5, 4, 33, 32, 43],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [277, 1, 48, 8, 9],
#  [7, 6, 10, 14, 54, 15, 20],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [7, 6, 10, 24, 38],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [17, 16, 293, 12, 54, 15, 427],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [2, 7, 6, 10, 14, 112, 15],
#  [142, 1, 48, 8, 9],
#  [29, 259, 82, 34, 90, 8, 9],
#  [992, 130, 1, 26, 90, 993, 109, 44, 994, 9],
#  [7, 6, 10, 25],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [1,
#   114,
#   352,
#   13,
#   308,
#   1,
#   114,
#   8,
#   9,
#   37,
#   995,
#   996,
#   14,
#   2,
#   997,
#   20,
#   22,
#   2,
#   313,
#   337,
#   74,
#   998,
#   28,
#   82],
#  [11, 2, 5, 4, 73, 300, 1, 371, 60, 19, 353, 90, 21, 93, 30],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [17, 16, 44, 14, 153],
#  [94, 8, 9, 24],
#  [1, 428, 26, 2, 7, 6, 10, 2, 429],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [7, 6, 10, 12, 15],
#  [1, 11, 5, 4],
#  [17, 16, 109, 162],
#  [17, 16, 14, 27, 999, 15],
#  [294,
#   1000,
#   21,
#   2,
#   1001,
#   31,
#   13,
#   1002,
#   23,
#   302,
#   5,
#   4,
#   25,
#   53,
#   2,
#   104,
#   528,
#   529],
#  [8, 9, 12, 69],
#  [7, 6, 10, 25],
#  [148, 5, 4, 33, 32, 43],
#  [3, 108, 2, 115, 7, 6, 10, 20, 24, 299],
#  [11, 186, 279, 2, 7, 6, 10],
#  [8, 9, 12, 77, 69],
#  [8, 9, 14, 91],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [7, 6, 10, 25],
#  [7, 6, 10, 24],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [2, 7, 6, 10, 25, 121, 118],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [7, 6, 10, 25],
#  [2, 7, 6, 10, 25, 121, 118],
#  [29, 259, 82, 34, 90, 8, 9],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [1, 68, 11, 19, 1003, 165, 39, 2, 17, 16, 430, 1004, 82, 13, 1005],
#  [7, 6, 10, 24],
#  [8, 9, 14, 54, 15, 20],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [2, 7, 6, 10, 25, 121, 118],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [1, 11, 5, 4],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [1,
#   350,
#   1006,
#   5,
#   4,
#   3,
#   1,
#   42,
#   135,
#   12,
#   116,
#   13,
#   308,
#   53,
#   56,
#   19,
#   1007,
#   90,
#   21],
#  [7, 6, 10, 25],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [3,
#   8,
#   9,
#   14,
#   27,
#   335,
#   3,
#   27,
#   133,
#   3,
#   530,
#   303,
#   660,
#   49,
#   19,
#   661,
#   37,
#   467,
#   316,
#   662,
#   19,
#   531,
#   13,
#   354,
#   372,
#   316,
#   1008],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [1, 11, 8, 9],
#  [5, 4, 14, 27, 620, 316, 306, 13, 615, 3, 663, 1, 11, 5, 4],
#  [7, 6, 10, 24],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1, 40, 89, 19, 304, 22, 2, 341, 17, 16, 44, 12, 15],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [7, 6, 10, 24],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [3, 1, 11, 8, 9, 93],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [17, 16, 109, 162],
#  [1, 11, 5, 4],
#  [1, 11, 5, 4],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [1, 18, 17, 16],
#  [664, 17, 16, 509, 34, 19, 56],
#  [17, 16, 44, 14, 153],
#  [101, 14, 2, 7, 6, 10, 51, 25, 32, 370],
#  [277, 1, 48, 8, 9],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [1, 11, 8, 9],
#  [1, 114, 2, 104, 17, 16],
#  [532, 1009, 665, 76, 2, 7, 6, 10, 51, 108, 2, 115, 14, 15],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [5, 4, 533],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [11, 186, 279, 2, 7, 6, 10],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [1, 11, 5, 4],
#  [1, 11, 5, 4],
#  [27, 8, 9, 14, 32, 64],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 11, 5, 4],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 114, 2, 104, 17, 16],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [21,
#   14,
#   15,
#   1,
#   404,
#   70,
#   29,
#   1010,
#   3,
#   1011,
#   1,
#   1012,
#   53,
#   13,
#   365,
#   3,
#   101,
#   1,
#   1013,
#   99,
#   1014,
#   1015,
#   1016,
#   3,
#   101,
#   55,
#   97,
#   19,
#   125,
#   17,
#   16,
#   293,
#   51,
#   14,
#   15],
#  [277, 1, 48, 8, 9],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [1,
#   14,
#   377,
#   31,
#   534,
#   2,
#   535,
#   5,
#   4,
#   88,
#   666,
#   667,
#   51,
#   12,
#   54,
#   15,
#   88,
#   3,
#   1,
#   136,
#   143,
#   19,
#   98,
#   2,
#   668,
#   41,
#   119,
#   21,
#   468,
#   45],
#  [7, 6, 10, 24],
#  [1, 11, 5, 4],
#  [7,
#   6,
#   10,
#   21,
#   12,
#   43,
#   1,
#   103,
#   2,
#   20,
#   536,
#   3,
#   1017,
#   132,
#   21,
#   14,
#   34,
#   3,
#   1018,
#   37,
#   63,
#   22,
#   20,
#   14,
#   53,
#   354,
#   101,
#   21,
#   351,
#   38,
#   298,
#   378],
#  [8, 9, 14, 133],
#  [8, 9, 14, 133],
#  [345, 11, 19, 307, 292, 7, 6, 10, 37, 431, 60, 537, 469],
#  [1, 11, 5, 4],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [2, 7, 6, 10, 25, 121, 118],
#  [2, 7, 6, 10, 12, 15],
#  [7, 6, 10, 14, 54, 15, 20],
#  [142, 1, 48, 8, 9],
#  [7, 6, 10, 14, 54, 15, 20],
#  [37, 8, 9, 12, 41, 31, 2, 110, 133, 33, 1, 89, 122, 128],
#  [2, 7, 6, 10, 12, 15],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 11, 5, 4],
#  [7, 6, 10, 25],
#  [2, 7, 6, 10, 12, 18, 41, 31, 2, 669, 301],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [11, 186, 279, 2, 7, 6, 10],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [8, 9, 14, 91],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [1,
#   48,
#   8,
#   9,
#   3,
#   1,
#   432,
#   128,
#   352,
#   37,
#   1,
#   116,
#   379,
#   18,
#   65,
#   59,
#   291,
#   63,
#   35,
#   42,
#   56,
#   99,
#   296,
#   35,
#   42,
#   22,
#   1,
#   112,
#   11,
#   8,
#   9,
#   291,
#   1,
#   11,
#   8,
#   9,
#   291,
#   8,
#   9,
#   12,
#   116,
#   13,
#   91,
#   123,
#   3,
#   538,
#   1019,
#   22,
#   291,
#   8,
#   9,
#   306,
#   13,
#   91,
#   670,
#   3,
#   332,
#   21,
#   303,
#   60,
#   1020,
#   322,
#   405,
#   305,
#   306,
#   19,
#   433,
#   21,
#   380,
#   60,
#   40,
#   322,
#   1021,
#   291,
#   1,
#   48,
#   8,
#   9,
#   291,
#   8,
#   1022,
#   20,
#   12,
#   91,
#   87,
#   19,
#   1023,
#   291,
#   3,
#   1,
#   120,
#   22,
#   8,
#   9,
#   12,
#   15,
#   291,
#   91,
#   1024,
#   1025,
#   96,
#   8,
#   9,
#   291,
#   1,
#   11,
#   392,
#   19,
#   2,
#   671,
#   3,
#   1,
#   11,
#   8,
#   9,
#   291,
#   117,
#   8,
#   9,
#   14,
#   298,
#   15,
#   93,
#   37,
#   57,
#   20,
#   291,
#   8,
#   9,
#   14,
#   15,
#   291,
#   8,
#   9,
#   51,
#   14,
#   15,
#   291,
#   1,
#   58,
#   1,
#   334,
#   40,
#   38,
#   1026,
#   23,
#   1,
#   112,
#   48,
#   8,
#   9,
#   3,
#   119,
#   35,
#   304,
#   35,
#   114,
#   317,
#   313,
#   20,
#   291,
#   8,
#   9,
#   12,
#   1027,
#   19,
#   38,
#   15,
#   291,
#   8,
#   9,
#   12,
#   91,
#   291,
#   107,
#   310,
#   56,
#   381,
#   1,
#   11,
#   8,
#   9,
#   37,
#   1,
#   58,
#   21,
#   333,
#   105,
#   19,
#   318,
#   22,
#   75,
#   672,
#   65,
#   102,
#   353,
#   90,
#   525,
#   3,
#   1028,
#   54,
#   466,
#   291,
#   1,
#   48,
#   8,
#   9,
#   300,
#   1,
#   58,
#   395,
#   52,
#   90,
#   61,
#   82,
#   188,
#   76,
#   673,
#   470,
#   23,
#   21,
#   406,
#   674,
#   22,
#   1029,
#   1030,
#   291,
#   1,
#   11,
#   8,
#   9,
#   3,
#   294,
#   27,
#   1031,
#   3,
#   1032,
#   22,
#   21,
#   303,
#   60,
#   458,
#   2,
#   322,
#   405,
#   3,
#   322,
#   675,
#   291,
#   8,
#   9,
#   14,
#   15,
#   291,
#   8,
#   9,
#   12,
#   1033,
#   39,
#   91,
#   1034,
#   3,
#   131,
#   291,
#   1,
#   11,
#   8,
#   9,
#   291,
#   1,
#   11,
#   8,
#   9,
#   291,
#   206,
#   280,
#   1,
#   129,
#   281,
#   3,
#   1,
#   11,
#   8,
#   9,
#   291,
#   8,
#   9,
#   14,
#   27,
#   15,
#   291,
#   8,
#   9,
#   14,
#   54,
#   15,
#   20,
#   291,
#   142,
#   1,
#   48,
#   8,
#   9,
#   291,
#   277,
#   1,
#   48,
#   8,
#   9,
#   291,
#   1,
#   170,
#   11,
#   8,
#   9,
#   46,
#   58,
#   61,
#   127,
#   22,
#   211,
#   12,
#   187,
#   105,
#   188,
#   291,
#   169,
#   146,
#   72,
#   1,
#   11,
#   8,
#   9],
#  [7, 6, 10, 25],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [539, 1035, 1036, 39, 407, 314, 461, 106, 315, 17, 16, 12, 53, 34, 65],
#  [7, 6, 10, 12, 15],
#  [2, 7, 6, 10, 14, 112, 15],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [1, 93, 18, 5, 4],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [540, 7, 6, 10, 3, 21, 25],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [29, 259, 82, 34, 90, 8, 9],
#  [1, 11, 5, 4],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [8, 9, 14, 27, 15],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [1, 11, 5, 4],
#  [7, 6, 10, 25, 1037],
#  [2, 7, 6, 10, 14, 112, 15],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [8, 9, 12, 77, 69],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [2, 7, 6, 10, 25, 121, 118],
#  [3, 94, 2, 7, 6, 10, 12, 1038, 676, 3, 133],
#  [17, 16, 44, 14, 15],
#  [8, 9, 14, 91],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [5, 4, 24, 21, 434, 19, 38, 137],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [1, 350, 541, 5, 4, 677],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [1, 11, 8, 9],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [1, 48, 2, 7, 6, 10],
#  [1, 26, 5, 4],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [1, 114, 2, 104, 17, 16],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [1, 114, 2, 104, 17, 16],
#  [330, 1, 11, 5, 4, 18, 13, 542, 678, 522, 1039],
#  [7, 6, 10, 12, 15],
#  [1, 11, 2, 7, 6, 10],
#  [37, 17, 16, 44, 24],
#  [2, 7, 6, 10, 12, 15],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1, 26, 5, 4],
#  [8, 9, 14, 133],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [8, 9, 14, 27, 15],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [7, 6, 10, 25],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [1, 93, 18, 5, 4],
#  [7, 6, 10, 12, 15],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [17, 16, 109, 162],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [7, 6, 10, 14, 54, 15, 20],
#  [17, 16, 109, 162],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [2, 7, 6, 10, 25, 121, 118],
#  [1, 11, 8, 9],
#  [1, 114, 2, 104, 17, 16],
#  [1, 295, 2, 7, 6, 10],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [7, 6, 10, 24],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [2, 7, 6, 10, 25, 121, 118],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [2, 7, 6, 10, 14, 13, 32, 92, 20],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [142, 1, 48, 8, 9],
#  [8, 9, 14, 27, 15],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [7, 6, 10, 24],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [8, 9, 14, 54, 15, 20],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [8, 9, 14, 54, 15, 20],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [3,
#   1,
#   114,
#   2,
#   5,
#   4,
#   679,
#   29,
#   680,
#   14,
#   460,
#   56,
#   408,
#   2,
#   149,
#   336,
#   99,
#   2,
#   149,
#   118],
#  [1, 48, 2, 7, 6, 10],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [1, 11, 2, 7, 6, 10],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [1, 11, 8, 9],
#  [7, 6, 10, 24],
#  [1, 26, 5, 4],
#  [8, 9, 14, 27, 15],
#  [1, 11, 5, 4],
#  [1, 93, 18, 5, 4],
#  [7, 6, 10, 12, 41, 91, 20],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1, 11, 8, 9],
#  [1, 114, 2, 104, 17, 16],
#  [1, 11, 8, 9],
#  [7, 6, 10, 24, 299],
#  [107,
#   310,
#   56,
#   381,
#   1,
#   18,
#   5,
#   4,
#   37,
#   1,
#   543,
#   13,
#   1040,
#   20,
#   31,
#   13,
#   471,
#   435,
#   409,
#   467,
#   76,
#   13,
#   365],
#  [1, 11, 8, 9],
#  [2, 7, 6, 10, 12, 15],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [1, 11, 5, 4],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [29, 259, 82, 34, 90, 8, 9],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1, 11, 5, 4],
#  [1, 93, 18, 5, 4],
#  [1, 432, 128, 1041, 355, 1042, 56, 61, 629, 37, 1, 40, 11, 8, 9],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [7, 6, 10, 25],
#  [8, 9, 25],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [1, 18, 1043, 17, 16, 41],
#  [2, 7, 6, 10, 12, 15],
#  [17, 16, 44, 14, 153],
#  [101, 189, 50, 8, 9, 51, 12, 2, 110, 64, 20, 1, 89, 122, 128],
#  [17, 16, 109, 162],
#  [8, 9, 14, 54, 15, 20],
#  [1, 11, 8, 9],
#  [2, 7, 6, 10, 12, 15],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [1, 11, 5, 4],
#  [148, 5, 4, 33, 32, 43],
#  [8, 9, 12, 77, 69],
#  [1044, 1, 346, 460, 8, 9, 436],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [2, 65, 66, 59, 172, 21, 42, 62, 30, 1, 11, 2, 7, 6, 10],
#  [148, 5, 4, 33, 32, 43],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [148, 5, 4, 33, 32, 43],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [8, 9, 12, 15],
#  [7, 6, 10, 24, 38],
#  [1,
#   26,
#   21,
#   300,
#   23,
#   1,
#   32,
#   18,
#   67,
#   17,
#   16,
#   456,
#   27,
#   1,
#   379,
#   370,
#   119,
#   1,
#   307,
#   292,
#   373,
#   76,
#   437,
#   332,
#   294,
#   681,
#   438,
#   76,
#   67,
#   682,
#   439,
#   22],
#  [8, 9, 14, 91],
#  [7, 6, 10, 12, 13, 1045, 15, 88],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [51,
#   12,
#   356,
#   683,
#   5,
#   4,
#   1046,
#   1047,
#   31,
#   1048,
#   31,
#   1049,
#   31,
#   1050,
#   18,
#   373,
#   296,
#   1051,
#   26,
#   5,
#   4,
#   3,
#   58,
#   57,
#   12,
#   13,
#   34,
#   684],
#  [1, 18, 19, 685, 17, 16],
#  [7, 6, 10, 24],
#  [2, 7, 6, 10, 14, 112, 15],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [7, 6, 10, 14, 54, 15, 20],
#  [7, 6, 10, 24],
#  [1, 11, 5, 4],
#  [117,
#   63,
#   395,
#   27,
#   544,
#   299,
#   19,
#   1052,
#   21,
#   340,
#   17,
#   16,
#   1053,
#   22,
#   68,
#   38,
#   176,
#   319],
#  [7, 6, 10, 14, 54, 15, 20],
#  [17, 16, 44, 14, 153],
#  [142, 1, 48, 8, 9],
#  [1, 11, 686, 1054, 408, 28, 30, 28, 1, 11, 1055, 2, 7, 6, 10],
#  [1, 26, 5, 4],
#  [29, 259, 82, 34, 90, 8, 9],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [1, 440, 2, 7, 6, 10, 24],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [11, 186, 279, 2, 7, 6, 10],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [1, 11, 5, 4],
#  [7, 6, 10, 12, 15],
#  [72, 334, 35, 545, 117, 1, 11, 17, 16, 441],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [442, 2, 7, 6, 10, 24],
#  [1, 11, 2, 7, 6, 10],
#  [8, 9, 14, 54, 15, 20],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [472,
#   379,
#   70,
#   19,
#   144,
#   2,
#   410,
#   299,
#   687,
#   45,
#   19,
#   2,
#   688,
#   689,
#   17,
#   16,
#   293,
#   14,
#   92],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1, 116, 11, 8, 9, 3, 690, 1056],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [29, 259, 82, 34, 90, 8, 9],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [5, 4, 24],
#  [53, 22, 37, 332, 21, 14, 29, 630, 81, 12, 50, 5, 4],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [37, 1, 11, 8, 9],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [169, 146, 72, 1, 11, 8, 9],
#  [8, 9, 14, 54, 15, 20],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [7, 6, 10, 24],
#  [2, 7, 6, 10, 12, 15],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [2, 7, 6, 10, 14, 77, 15],
#  [1, 11, 8, 9],
#  [277, 1, 48, 8, 9],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [7, 6, 10, 24],
#  [1, 11, 8, 9],
#  [2, 7, 6, 10, 25, 121, 118],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [1, 11, 8, 9],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1, 11, 8, 9],
#  [17, 16, 44, 14, 54, 15, 20],
#  [8, 9, 12, 77, 69],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [1, 11, 8, 9, 37, 61, 32, 335],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [17, 16, 109, 162],
#  [2, 7, 6, 10, 25, 18, 13, 691],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [7, 6, 10, 2, 20, 25],
#  [1, 11, 5, 4],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [17, 16, 44, 14, 153],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [7, 6, 10, 24],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [1, 18, 17, 16],
#  [7, 6, 10, 24],
#  [2, 7, 6, 10, 14, 112, 15],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [17, 16, 44, 14, 153],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [142, 1, 48, 8, 9],
#  [8, 9, 14, 27, 15],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [8, 9, 12, 77, 69],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [29, 1057, 14, 1058, 17, 16, 44, 14, 13, 692, 20],
#  [2, 7, 6, 10, 25, 121, 118],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [8, 9, 12, 77, 69],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [8, 9, 14, 133],
#  [8, 9, 14, 91],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [8, 9, 14, 27, 15],
#  [2, 7, 6, 10, 12, 41, 31, 2, 110, 91, 33, 331, 122, 128],
#  [1, 11, 5, 4],
#  [311, 1, 83, 1, 97, 3, 103, 17, 16, 44, 51, 14, 15],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [7, 6, 10, 14, 54, 15, 20],
#  [1059, 117, 305, 102, 296, 693, 8, 9, 24],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [7, 6, 10, 14, 54, 15, 20],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [1, 93, 18, 5, 4],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [142, 1, 48, 8, 9],
#  [7, 6, 10, 12, 15],
#  [1, 26, 57, 8, 9, 357],
#  [1, 434, 19, 26, 5, 4, 3, 309, 294, 13, 1060],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [142, 1, 48, 8, 9],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [2, 79, 31, 5, 4, 12, 13, 212, 3, 213, 41, 3, 1, 11, 5, 4],
#  [7, 6, 10, 24],
#  [7, 6, 10, 25],
#  [1, 26, 5, 4],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [1, 11, 5, 4],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [8, 9, 12, 77, 69],
#  [1, 11, 8, 9, 37, 22, 12, 131, 13, 1061, 1062, 694, 53, 322, 695],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [1, 93, 18, 5, 4],
#  [7, 6, 10, 12, 27, 15],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [7, 6, 10, 25],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [306, 54, 378, 1063, 39, 41, 31, 2, 1064, 1, 546, 53, 90, 62, 7, 6, 10, 24],
#  [7, 6, 10, 24],
#  [1, 11, 8, 9, 23, 21, 12, 13, 127, 79, 127, 696],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [8, 9, 12, 77, 69],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [1, 114, 2, 104, 17, 16],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [1, 11, 5, 4],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [7, 6, 10, 24, 38],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [23,
#   1,
#   68,
#   18,
#   19,
#   166,
#   154,
#   66,
#   18,
#   2,
#   149,
#   130,
#   1,
#   18,
#   3,
#   1,
#   32,
#   18,
#   5,
#   4,
#   27,
#   1,
#   111,
#   22,
#   278,
#   13,
#   185,
#   18,
#   57,
#   68,
#   38,
#   13,
#   92,
#   87],
#  [8, 9, 14, 91],
#  [1, 369, 8, 1065, 21, 1066],
#  [29, 259, 82, 34, 90, 8, 9],
#  [1, 114, 2, 104, 17, 16],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [7, 6, 10, 24, 38],
#  [7, 6, 10, 24],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [345, 40, 18, 19, 304, 22, 8, 9, 12, 13, 314, 64, 20],
#  [11, 186, 279, 2, 7, 6, 10],
#  [8, 9, 14, 133],
#  [7, 6, 10, 12, 15],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [1, 11, 8, 9],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [473, 186, 8, 9, 330],
#  [8, 9, 12, 77, 69],
#  [7, 6, 10, 14, 54, 15, 20],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [1, 112, 11, 5, 4, 28, 35, 102, 358, 328],
#  [7, 6, 10, 24],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [8, 9, 14, 54, 15, 20],
#  [76, 313, 436, 2, 7, 6, 10, 24, 13, 1067, 326],
#  [277, 1, 48, 8, 9],
#  [27, 8, 9, 14, 32, 64],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [1, 11, 5, 4],
#  [1,
#   49,
#   19,
#   38,
#   84,
#   23,
#   1,
#   11,
#   5,
#   4,
#   3,
#   1,
#   32,
#   49,
#   13,
#   183,
#   174,
#   65,
#   168,
#   21,
#   275,
#   37,
#   21,
#   12,
#   116,
#   27,
#   30,
#   175],
#  [2, 7, 6, 10, 25, 121, 118],
#  [7, 6, 10, 24],
#  [1,
#   58,
#   1,
#   1068,
#   19,
#   26,
#   7,
#   6,
#   10,
#   40,
#   23,
#   21,
#   333,
#   1069,
#   2,
#   1070,
#   65,
#   76,
#   1071],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [2, 7, 6, 10, 14, 112, 15],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [1, 11, 2, 7, 6, 10],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [5, 4, 12, 92, 37, 161, 75, 547, 31, 347],
#  [2, 7, 6, 10, 12, 15],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [17, 16, 109, 162],
#  [8, 9, 12, 54, 15, 20],
#  [8, 9, 12, 77, 69],
#  [2, 7, 6, 10, 14, 112, 15],
#  [206, 280, 1, 129, 281, 3, 1, 11, 8, 9],
#  [7, 6, 10, 24],
#  [34, 8, 9],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [7, 6, 10, 12, 15],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [8, 9, 12, 77, 69],
#  [80, 3, 8, 9, 12, 13, 78, 20],
#  [57, 268, 24, 3, 5, 4, 24, 86, 269],
#  [7, 6, 10, 25],
#  [86, 8, 9, 12, 131, 13, 69, 20],
#  [17, 16, 44, 14, 153],
#  [28,
#   1,
#   228,
#   84,
#   141,
#   2,
#   229,
#   20,
#   196,
#   1,
#   47,
#   230,
#   31,
#   62,
#   30,
#   1,
#   231,
#   2,
#   20,
#   8,
#   9],
#  [51,
#   12,
#   72,
#   1,
#   132,
#   239,
#   240,
#   198,
#   50,
#   199,
#   241,
#   1,
#   14,
#   242,
#   18,
#   243,
#   17,
#   16,
#   36,
#   22,
#   200],
#  [3,
#   294,
#   60,
#   302,
#   377,
#   31,
#   697,
#   76,
#   1072,
#   527,
#   19,
#   56,
#   1073,
#   40,
#   17,
#   16,
#   330,
#   1,
#   626,
#   43,
#   93,
#   30,
#   1074],
#  [27, 8, 9, 14, 32, 64],
#  [8, 9, 14, 91],
#  [81,
#   214,
#   56,
#   215,
#   29,
#   216,
#   150,
#   190,
#   19,
#   29,
#   191,
#   3,
#   81,
#   217,
#   99,
#   29,
#   34,
#   8,
#   9,
#   192,
#   193],
#  [8, 9, 14, 15],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [8, 9, 14, 27, 15],
#  [74, 204, 18, 125, 17, 16, 46, 260],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [302,
#   63,
#   1,
#   47,
#   60,
#   13,
#   121,
#   399,
#   31,
#   106,
#   315,
#   1,
#   89,
#   1075,
#   19,
#   11,
#   17,
#   16,
#   302,
#   113,
#   61,
#   1076,
#   73],
#  [148, 5, 4, 33, 32, 43],
#  [169, 146, 72, 1, 11, 8, 9],
#  [1077,
#   109,
#   14,
#   698,
#   1078,
#   19,
#   38,
#   13,
#   616,
#   359,
#   20,
#   37,
#   13,
#   78,
#   699,
#   53,
#   2,
#   700,
#   17,
#   16],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [80, 3, 8, 9, 14, 13, 78, 20],
#  [7, 6, 10, 70, 70, 36, 36, 83, 52, 83, 52, 184, 13, 43],
#  [8, 9, 12, 77, 69],
#  [2, 134, 207, 3, 17, 16, 44, 140, 74, 15, 33],
#  [2, 7, 6, 10, 14, 112, 15],
#  [1, 11, 5, 4],
#  [1, 346, 5, 4, 3, 1079, 474],
#  [1, 11, 8, 9],
#  [1, 170, 11, 8, 9, 46, 58, 61, 127, 22, 211, 12, 187, 105, 188],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [148, 5, 4, 33, 32, 43],
#  [1080,
#   2,
#   7,
#   6,
#   10,
#   12,
#   13,
#   91,
#   1081,
#   1082,
#   31,
#   382,
#   22,
#   1083,
#   39,
#   2,
#   422,
#   3,
#   124,
#   1084,
#   21],
#  [1, 26, 5, 4, 22, 209, 289, 210, 13, 77, 290],
#  [325, 1, 475, 57, 406, 429, 70, 18, 8, 9],
#  [1, 94, 48, 8, 9],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [7, 6, 10, 12, 15],
#  [1, 48, 7, 6, 10],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [1, 11, 8, 9],
#  [1, 11, 5, 4],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [11, 186, 279, 2, 7, 6, 10],
#  [8, 9, 14, 91],
#  [7, 6, 10, 24],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [1, 11, 2, 7, 6, 10],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [148, 5, 4, 33, 32, 43],
#  [1, 93, 18, 5, 4],
#  [8, 9, 12, 131, 54, 15, 20],
#  [155, 282, 45, 39, 283, 3, 55, 97, 3, 103, 2, 7, 6, 10, 25],
#  [1, 11, 8, 9],
#  [1, 26, 5, 4],
#  [169, 146, 72, 1, 11, 8, 9],
#  [55, 94, 97, 19, 292, 8, 9, 51, 383, 25],
#  [1, 11, 2, 7, 6, 10],
#  [2, 7, 6, 10, 14, 112, 15],
#  [7, 6, 10, 12, 15],
#  [40, 53, 2, 701, 8, 9, 14, 13, 78, 20],
#  [151, 173, 124, 1, 49, 60, 85, 197, 178, 5, 4],
#  [8, 9, 12, 77, 69],
#  [1, 47, 126, 19, 87, 71, 2, 5, 4, 73, 147, 23, 22, 12, 41, 15, 79],
#  [8, 9, 14, 133],
#  [311, 411, 1, 97, 39, 1085, 476, 19, 292, 2, 7, 6, 10, 51, 25],
#  [1, 18, 17, 16, 33, 23, 35, 145, 42, 205, 96, 2, 52, 167],
#  [108, 2, 115, 2, 7, 6, 10, 25, 40, 276, 35, 42],
#  [1, 177, 226, 19, 227, 7, 6, 10, 28, 13, 123],
#  [1,
#   11,
#   2,
#   5,
#   4,
#   73,
#   63,
#   35,
#   102,
#   232,
#   22,
#   28,
#   13,
#   88,
#   94,
#   233,
#   76,
#   2,
#   234,
#   235,
#   236,
#   2,
#   237,
#   238,
#   138],
#  [8, 9, 14, 27, 15],
#  [1, 94, 26, 2, 7, 6, 10],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [11, 186, 279, 2, 7, 6, 10],
#  [1, 11, 5, 4],
#  [1,
#   58,
#   1,
#   26,
#   5,
#   4,
#   23,
#   21,
#   286,
#   30,
#   137,
#   71,
#   287,
#   45,
#   135,
#   3,
#   2,
#   33,
#   59,
#   40,
#   288,
#   34,
#   19,
#   208,
#   39],
#  [17, 16, 44, 14, 153],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [27,
#   28,
#   218,
#   171,
#   12,
#   219,
#   2,
#   194,
#   220,
#   221,
#   29,
#   222,
#   3,
#   55,
#   223,
#   45,
#   18,
#   176,
#   17,
#   16],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [1, 11, 82, 13, 261, 53, 17, 16, 3, 13, 262, 53, 263],
#  [2, 7, 6, 10, 14, 15, 1, 136, 143, 19, 98, 21],
#  [21,
#   14,
#   1086,
#   27,
#   325,
#   1087,
#   1,
#   14,
#   1088,
#   67,
#   1089,
#   5,
#   4,
#   1090,
#   365,
#   1,
#   1091],
#  [1, 11, 5, 4],
#  [1, 120, 22, 2, 7, 6, 10, 24, 548, 702, 19, 2, 88],
#  [94, 2, 7, 6, 10, 12, 15],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  [12, 21, 40, 56, 46, 156, 5, 4, 43],
#  [2, 7, 6, 10, 12, 15],
#  [2, 7, 6, 10, 12, 15],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [5, 4, 12, 15, 1, 107, 182, 63, 159, 160, 274],
#  [2, 7, 6, 10, 14, 112, 15],
#  [1, 93, 18, 5, 4],
#  [270, 2, 158, 181, 113, 271, 3, 272, 273, 2, 7, 6, 10, 24],
#  [1, 11, 8, 9],
#  [277, 1, 48, 8, 9],
#  [148, 5, 4, 33, 32, 43],
#  [5,
#   4,
#   244,
#   245,
#   246,
#   100,
#   163,
#   247,
#   36,
#   201,
#   67,
#   248,
#   3,
#   25,
#   164,
#   50,
#   67,
#   249,
#   39,
#   250,
#   144,
#   251,
#   252,
#   3,
#   253,
#   3,
#   254,
#   165,
#   2,
#   255,
#   256,
#   257,
#   157],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 11, 264, 265, 266, 267, 3, 17, 16, 106, 28, 117],
#  [8, 9, 14, 27, 15],
#  [2, 7, 6, 10, 12, 15],
#  [309,
#   1,
#   47,
#   2,
#   104,
#   152,
#   19,
#   304,
#   22,
#   2,
#   7,
#   6,
#   10,
#   24,
#   37,
#   1092,
#   21,
#   100,
#   163,
#   13,
#   422],
#  [169, 146, 72, 1, 11, 8, 9],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [11, 186, 279, 2, 7, 6, 10],
#  [60,
#   23,
#   1,
#   26,
#   5,
#   4,
#   37,
#   23,
#   1,
#   47,
#   2,
#   202,
#   31,
#   152,
#   22,
#   258,
#   21,
#   119,
#   2,
#   179,
#   180,
#   203],
#  [1, 120, 7, 6, 10, 25, 195, 30, 75, 224, 225],
#  [1, 26, 5, 4, 61, 284, 139, 3, 34, 3, 161, 75, 41, 285, 85],
#  ...]

# %% [markdown]
# Y rellenamos con "0"

# %%
seq_len_max =100
text_df_seq = pad_sequences(sequences, maxlen=seq_len_max )

# %%
text_df_seq
# Out:
# array([[  0,   0,   0, ..., 187, 105, 188],
#        [  0,   0,   0, ...,  14,  27,  15],
#        [  0,   0,   0, ...,  89, 122, 128],
#        ...,
#        [  0,   0,   0, ...,  11,   8,   9],
#        [  0,   0,   0, ...,  18,  17,  16],
#        [  0,   0,   0, ..., 256, 257, 157]])

# %%
np.shape(text_df_seq)
# Out:
# (6918, 100)

# %% [markdown]
# Creamos las muestras de entrenamiento, validación y test

# %%
print(6918*.6, 6918*.8) #entrenamiento 70%, validación 15%, test 15%
# Out:
# 4150.8 5534.400000000001

# %%
X_train = text_df_seq[0:4150,]
X_val = text_df_seq[4150:5534,]
X_test = text_df_seq[5534:,]

# %%
np.shape(X_train)
# Out:
# (4150, 100)

# %%
np.shape(X_val)
# Out:
# (1384, 100)

# %%
np.shape(X_test)
# Out:
# (1384, 100)

# %%
y_train = df.label[0:4150,]
y_val = df.label[4150:5534,]
y_test = df.label[5534:,]

# %%
np.shape(y_train)
# Out:
# (4150,)

# %%
np.shape(y_val)
# Out:
# (1384,)

# %%
np.shape(y_test)
# Out:
# (1384,)

# %% [markdown]
# ## Red Secuencial

# %% [markdown]
# Creamos la arquitectura en una función

# %%
def create_model(units_RNN = 1):
    model_input = Input(shape=(seq_len_max,), dtype='int32')
    embedded_layer = Embedding(len(tokenizer.word_index)+1, 100, embeddings_initializer='uniform')(model_input)
    recu_layer = SimpleRNN(units=units_RNN, activation='tanh', use_bias=True) (embedded_layer)
   
    model_ouput = Dense(1, activation='sigmoid')(recu_layer)

    model = Model(model_input, model_ouput)
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['acc'])


    return model

# %%
modelo=create_model()

print(modelo.summary())
SVG(model_to_dot(modelo,show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 100, 100)          223600
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 1)                 102
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 223,704
# Trainable params: 223,704
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Entrenamos

# %%
modelo.fit(X_train, y_train, validation_data=(X_val, y_val),
          epochs=10, batch_size=128)
# Out:
# Train on 4150 samples, validate on 1384 samples
# Epoch 1/10
# 4150/4150 [==============================] - 2s 367us/step - loss: 0.4833 - acc: 0.8766 - val_loss: 0.4230 - val_acc: 0.8945
# Epoch 2/10
# 4150/4150 [==============================] - 1s 309us/step - loss: 0.3793 - acc: 0.9277 - val_loss: 0.3675 - val_acc: 0.9227
# Epoch 3/10
# 4150/4150 [==============================] - 1s 330us/step - loss: 0.3350 - acc: 0.9492 - val_loss: 0.3389 - val_acc: 0.9314
# Epoch 4/10
# 4150/4150 [==============================] - 1s 318us/step - loss: 0.3087 - acc: 0.9586 - val_loss: 0.3230 - val_acc: 0.9342
# Epoch 5/10
# 4150/4150 [==============================] - 1s 308us/step - loss: 0.2907 - acc: 0.9634 - val_loss: 0.3131 - val_acc: 0.9350
# Epoch 6/10
# 4150/4150 [==============================] - 1s 301us/step - loss: 0.2768 - acc: 0.9677 - val_loss: 0.3061 - val_acc: 0.9357
# Epoch 7/10
# 4150/4150 [==============================] - 1s 300us/step - loss: 0.2645 - acc: 0.9718 - val_loss: 0.2979 - val_acc: 0.9422
# Epoch 8/10
# 4150/4150 [==============================] - 1s 294us/step - loss: 0.2538 - acc: 0.9754 - val_loss: 0.2908 - val_acc: 0.9393
# Epoch 9/10
# 4150/4150 [==============================] - 1s 291us/step - loss: 0.2438 - acc: 0.9761 - val_loss: 0.2838 - val_acc: 0.9415
# Epoch 10/10
# 4150/4150 [==============================] - 1s 285us/step - loss: 0.2347 - acc: 0.9778 - val_loss: 0.2774 - val_acc: 0.9436

# %% [markdown]
# Evaluamos el modelo

# %%
modelo.evaluate(X_test, y_test)
# Out:
# 1384/1384 [==============================] - 0s 179us/step
# [0.2711401714410396, 0.9450867052023122]

# %%
X_test
# Out:
# array([[  0,   0,   0, ...,   9,  14,  15],
#        [  0,   0,   0, ...,  13,  92,  87],
#        [  0,   0,   0, ...,  27,  30, 175],
#        ...,
#        [  0,   0,   0, ...,  11,   8,   9],
#        [  0,   0,   0, ...,  18,  17,  16],
#        [  0,   0,   0, ..., 256, 257, 157]])

# %%
y_pred_proba = modelo.predict(X_test)
y_pred = np.round(y_pred_proba)
print('')
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.94      0.94       587
#           1       0.95      0.95      0.95       797
#
# avg / total       0.95      0.95      0.95      1384

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'RNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('ROC in test')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()
plt.show()
plt.hist(y_pred_proba)
plt.show()

# %% [markdown]
# El modelo presenta un gran poder predictivo
# Con sólo una unidad RNN ya tiene un gran poder predictivo:
#
#              precision    recall  f1-score   support
#
#           0       0.98      0.97      0.97       579
#           1       0.98      0.99      0.98       805
#
#       total(avg)  0.98      0.98      0.98      1384
#
# Ahora vamos a probar con 5 unidades

# %%
modelo=create_model(5)

print(modelo.summary())
SVG(model_to_dot(modelo,show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 100, 100)          223600
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 5)                 530
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 224,136
# Trainable params: 224,136
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Entrenamos

# %%
modelo.fit(X_train, y_train, validation_data=(X_val, y_val),
          epochs=10, batch_size=128)
# Out:
# Train on 4150 samples, validate on 1384 samples
# Epoch 1/10
# 4150/4150 [==============================] - 2s 376us/step - loss: 0.4527 - acc: 0.8858 - val_loss: 0.3560 - val_acc: 0.9227
# Epoch 2/10
# 4150/4150 [==============================] - 1s 320us/step - loss: 0.2910 - acc: 0.9573 - val_loss: 0.2615 - val_acc: 0.9465
# Epoch 3/10
# 4150/4150 [==============================] - 1s 358us/step - loss: 0.2118 - acc: 0.9759 - val_loss: 0.2039 - val_acc: 0.9545
# Epoch 4/10
# 4150/4150 [==============================] - 1s 354us/step - loss: 0.1617 - acc: 0.9831 - val_loss: 0.1706 - val_acc: 0.9559
# Epoch 5/10
# 4150/4150 [==============================] - 1s 355us/step - loss: 0.1282 - acc: 0.9855 - val_loss: 0.1481 - val_acc: 0.9581
# Epoch 6/10
# 4150/4150 [==============================] - 1s 355us/step - loss: 0.1041 - acc: 0.9875 - val_loss: 0.1293 - val_acc: 0.9632
# Epoch 7/10
# 4150/4150 [==============================] - 1s 356us/step - loss: 0.0862 - acc: 0.9899 - val_loss: 0.1168 - val_acc: 0.9653
# Epoch 8/10
# 4150/4150 [==============================] - 1s 353us/step - loss: 0.0716 - acc: 0.9916 - val_loss: 0.1071 - val_acc: 0.9668
# Epoch 9/10
# 4150/4150 [==============================] - 1s 349us/step - loss: 0.0601 - acc: 0.9928 - val_loss: 0.1016 - val_acc: 0.9639
# Epoch 10/10
# 4150/4150 [==============================] - 1s 359us/step - loss: 0.0507 - acc: 0.9928 - val_loss: 0.0949 - val_acc: 0.9668

# %% [markdown]
# Evaluamos el modelo

# %%
modelo.evaluate(X_test, y_test)
# Out:
# 1384/1384 [==============================] - 0s 226us/step
# [0.08545893025880603, 0.9754335260115607]

# %%
X_test
# Out:
# array([[  0,   0,   0, ...,   9,  14,  15],
#        [  0,   0,   0, ...,  13,  92,  87],
#        [  0,   0,   0, ...,  27,  30, 175],
#        ...,
#        [  0,   0,   0, ...,  11,   8,   9],
#        [  0,   0,   0, ...,  18,  17,  16],
#        [  0,   0,   0, ..., 256, 257, 157]])

# %%
y_pred_proba = modelo.predict(X_test)
y_pred = np.round(y_pred_proba)
print('')
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.97      0.97       587
#           1       0.98      0.98      0.98       797
#
# avg / total       0.98      0.98      0.98      1384

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'RNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('ROC in test')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()
plt.show()
plt.hist(y_pred_proba)
plt.show()

# %% [markdown]
# Con cinco unidades RNN el modelo empeora luego, como pasa en muchas ocasiones un modelo más simple fuciona mejor que uno más complejo...
# Pero ¿qué pasa si usamos un Perceptron Multicapa?

# %%
def create_model2(units_dense = 1):
    model_input = Input(shape=(seq_len_max,), dtype='int32')
    embedded_layer = Embedding(len(tokenizer.word_index)+1, 100, embeddings_initializer='uniform')(model_input)
    embedded_layer = Flatten()(embedded_layer)
    dense = Dense(units=units_dense, activation='tanh', use_bias=True) (embedded_layer)
   
   
    model_ouput = Dense(1, activation='sigmoid')(dense)

    model = Model(model_input, model_ouput)
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['acc'])


    return model

# %%
modelo=create_model2(2)

print(modelo.summary())
SVG(model_to_dot(modelo,show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_4 (Embedding)      (None, 100, 100)          223600
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 20002
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 243,605
# Trainable params: 243,605
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Entrenamos

# %%
modelo.fit(X_train, y_train, validation_data=(X_val, y_val),
          epochs=10, batch_size=128)
# Out:
# Train on 4150 samples, validate on 1384 samples
# Epoch 1/10
# 4150/4150 [==============================] - 1s 146us/step - loss: 0.5419 - acc: 0.7993 - val_loss: 0.4152 - val_acc: 0.8829
# Epoch 2/10
# 4150/4150 [==============================] - 0s 84us/step - loss: 0.3419 - acc: 0.9439 - val_loss: 0.3089 - val_acc: 0.9552
# Epoch 3/10
# 4150/4150 [==============================] - 0s 83us/step - loss: 0.2656 - acc: 0.9713 - val_loss: 0.2608 - val_acc: 0.9595
# Epoch 4/10
# 4150/4150 [==============================] - 0s 82us/step - loss: 0.2228 - acc: 0.9831 - val_loss: 0.2270 - val_acc: 0.9668
# Epoch 5/10
# 4150/4150 [==============================] - 0s 82us/step - loss: 0.1945 - acc: 0.9901 - val_loss: 0.2050 - val_acc: 0.9754
# Epoch 6/10
# 4150/4150 [==============================] - 0s 80us/step - loss: 0.1740 - acc: 0.9945 - val_loss: 0.1905 - val_acc: 0.9747
# Epoch 7/10
# 4150/4150 [==============================] - 0s 79us/step - loss: 0.1583 - acc: 0.9969 - val_loss: 0.1754 - val_acc: 0.9827
# Epoch 8/10
# 4150/4150 [==============================] - 0s 80us/step - loss: 0.1454 - acc: 0.9978 - val_loss: 0.1650 - val_acc: 0.9841
# Epoch 9/10
# 4150/4150 [==============================] - 0s 81us/step - loss: 0.1349 - acc: 0.9993 - val_loss: 0.1555 - val_acc: 0.9834
# Epoch 10/10
# 4150/4150 [==============================] - 0s 82us/step - loss: 0.1257 - acc: 0.9995 - val_loss: 0.1479 - val_acc: 0.9841

# %% [markdown]
# Evaluamos el modelo

# %%
modelo.evaluate(X_test, y_test)
# Out:
# 1384/1384 [==============================] - 0s 43us/step
# [0.14733835262370248, 0.9848265895953757]

# %%
X_test
# Out:
# array([[  0,   0,   0, ...,   9,  14,  15],
#        [  0,   0,   0, ...,  13,  92,  87],
#        [  0,   0,   0, ...,  27,  30, 175],
#        ...,
#        [  0,   0,   0, ...,  11,   8,   9],
#        [  0,   0,   0, ...,  18,  17,  16],
#        [  0,   0,   0, ..., 256, 257, 157]])

# %%
y_pred_proba = modelo.predict(X_test)
y_pred = np.round(y_pred_proba)
print('')
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.98       587
#           1       0.98      0.99      0.99       797
#
# avg / total       0.98      0.98      0.98      1384

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'RNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('ROC in test')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()
plt.show()
plt.hist(y_pred_proba)
plt.show()

# %% [markdown]
# En este caso al ser un modelo de juguete (toy model) y unos datos de juguete tanbién da buenos resultados. Tengo la sensación que la capa de "Embedding" facilita mucho el trabajo y es parte del éxito del modelo

# %% [markdown]
# Ahora probaremos directamente la capa Embedding conectada a la sigmoid

# %%
def create_model3():
    model_input = Input(shape=(seq_len_max,), dtype='int32')
    embedded_layer = Embedding(len(tokenizer.word_index)+1, 100, embeddings_initializer='uniform')(model_input)
    embedded_layer = Flatten()(embedded_layer)

     
    model_ouput = Dense(1, activation='sigmoid')(embedded_layer)

    model = Model(model_input, model_ouput)
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['acc'])


    return model

# %%
modelo=create_model3()

print(modelo.summary())
SVG(model_to_dot(modelo,show_shapes=True).create(prog='dot', format='svg'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 100, 100)          223600
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 10001
# =================================================================
# Total params: 233,601
# Trainable params: 233,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Entrenamos

# %%
modelo.fit(X_train, y_train, validation_data=(X_val, y_val),
          epochs=10, batch_size=128)
# Out:
# Train on 4150 samples, validate on 1384 samples
# Epoch 1/10
# 4150/4150 [==============================] - 0s 119us/step - loss: 0.5603 - acc: 0.7617 - val_loss: 0.4277 - val_acc: 0.8447
# Epoch 2/10
# 4150/4150 [==============================] - 0s 56us/step - loss: 0.3126 - acc: 0.9243 - val_loss: 0.2610 - val_acc: 0.8837
# Epoch 3/10
# 4150/4150 [==============================] - 0s 58us/step - loss: 0.1830 - acc: 0.9480 - val_loss: 0.1645 - val_acc: 0.9501
# Epoch 4/10
# 4150/4150 [==============================] - 0s 59us/step - loss: 0.1181 - acc: 0.9728 - val_loss: 0.1214 - val_acc: 0.9581
# Epoch 5/10
# 4150/4150 [==============================] - 0s 56us/step - loss: 0.0805 - acc: 0.9805 - val_loss: 0.0973 - val_acc: 0.9595
# Epoch 6/10
# 4150/4150 [==============================] - 0s 58us/step - loss: 0.0561 - acc: 0.9855 - val_loss: 0.0772 - val_acc: 0.9668
# Epoch 7/10
# 4150/4150 [==============================] - 0s 62us/step - loss: 0.0397 - acc: 0.9906 - val_loss: 0.0645 - val_acc: 0.9733
# Epoch 8/10
# 4150/4150 [==============================] - 0s 61us/step - loss: 0.0284 - acc: 0.9928 - val_loss: 0.0569 - val_acc: 0.9740
# Epoch 9/10
# 4150/4150 [==============================] - 0s 69us/step - loss: 0.0204 - acc: 0.9961 - val_loss: 0.0502 - val_acc: 0.9776
# Epoch 10/10
# 4150/4150 [==============================] - 0s 57us/step - loss: 0.0148 - acc: 0.9973 - val_loss: 0.0452 - val_acc: 0.9783

# %% [markdown]
# Evaluamos el modelo

# %%
modelo.evaluate(X_test, y_test)
# Out:
# 1384/1384 [==============================] - 0s 30us/step
# [0.05423714882139698, 0.9747109826589595]

# %%
X_test
# Out:
# array([[  0,   0,   0, ...,   9,  14,  15],
#        [  0,   0,   0, ...,  13,  92,  87],
#        [  0,   0,   0, ...,  27,  30, 175],
#        ...,
#        [  0,   0,   0, ...,  11,   8,   9],
#        [  0,   0,   0, ...,  18,  17,  16],
#        [  0,   0,   0, ..., 256, 257, 157]])

# %%
y_pred_proba = modelo.predict(X_test)
y_pred = np.round(y_pred_proba)
print('')
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.97      0.97       587
#           1       0.98      0.97      0.98       797
#
# avg / total       0.97      0.97      0.97      1384

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
fig, ax1 = plt.subplots(1,1)
ax1.plot(fpr, tpr, 'r-.', label = 'RNN (%2.2f)' % auc(fpr, tpr))
ax1.set_xlabel('False Positive Rate')
ax1.set_ylabel('True Positive Rate')
ax1.set_title('ROC in test')
ax1.plot(fpr, fpr, 'b-', label = 'Random Guess')
ax1.legend()
plt.show()
plt.hist(y_pred_proba)
plt.show()

# %% [markdown]
# Con este último modelo se confirma que el uso directo de la sigmoide es suficiente para entrenar
